# %%
# !cd
# Out:
# d:\Projects\ExperisAcademy\Exercises

# %%
# %cd L20191209
# Out:
# d:\Projects\ExperisAcademy\Exercises\L20191209

# %%
# !dir
# Out:
#  Volume in drive D is Media
#  Volume Serial Number is 8463-757E
#
#  Directory of d:\Projects\ExperisAcademy\Exercises\L20191209
#
# 09/12/2019  20:52    <DIR>          .
# 09/12/2019  20:52    <DIR>          ..
# 09/12/2019  20:52    <DIR>          .ipynb_checkpoints
# 09/12/2019  20:52            11,890 Exam3Solution_12_19.ipynb
# 09/12/2019  20:52            29,201 ex_pandas_dataframe.txt
# 09/12/2019  20:52                61 load.py
# 09/12/2019  20:52                32 load_to_local_namespace.py
# 09/12/2019  20:52         1,452,139 Magic_functions.ipynb
# 09/12/2019  20:52            54,322 Pandas.ipynb
# 09/12/2019  20:52            30,149 processed_pd_data_frame.txt
# 09/12/2019  20:52           276,661 Q4_Sergei_Merson.ipynb
# 09/12/2019  20:52                78 saved_code.py
#                9 File(s)      1,854,533 bytes
#                3 Dir(s)  170,913,181,696 bytes free

# %%
with open('ex_pandas_dataframe.txt','r') as file:
    raw_exs = file.read()

# %%
raw_exs
# Out:
# '1. Write a Pandas program to get the powers of an array values element-wise. \nNote: First array elements raised to powers from second array\nSample data: {\'X\':[78,85,96,80,86], \'Y\':[84,94,89,83,86],\'Z\':[86,97,96,72,83]}\nExpected Output:\nX Y Z\n0 78 84 86\n1 85 94 97\n2 96 89 96\n3 80 83 72\n4 86 86 83\n***\n\n2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels. \nSample Python dictionary data and list labels:\nexam_data = {\'name\': [\'Anastasia\', \'Dima\', \'Katherine\', \'James\', \'Emily\', \'Michael\', \'Matthew\', \'Laura\', \'Kevin\', \'Jonas\'],\n\'score\': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],\n\'attempts\': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],\n\'qualify\': [\'yes\', \'no\', \'yes\', \'no\', \'no\', \'yes\', \'yes\', \'no\', \'no\', \'yes\']}\nlabels = [\'a\', \'b\', \'c\', \'d\', \'e\', \'f\', \'g\', \'h\', \'i\', \'j\']\nExpected Output:\nattempts name qualify score\na 1 Anastasia yes 
# ...

# %%
# Initial split by exercises:
separated_exs = [ex.strip() for ex in raw_exs.split('***')]
separated_exs
# Out:
# ["1. Write a Pandas program to get the powers of an array values element-wise. \nNote: First array elements raised to powers from second array\nSample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}\nExpected Output:\nX Y Z\n0 78 84 86\n1 85 94 97\n2 96 89 96\n3 80 83 72\n4 86 86 83",
#  "2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels. \nSample Python dictionary data and list labels:\nexam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],\n'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],\n'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],\n'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}\nlabels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']\nExpected Output:\nattempts name qualify score\na 1 Anastasia yes 12.5\nb 3 Dima no 9.0\n.... i 2 Kevin no 8.0\nj 1 Jonas yes 19.0",
# ...

# %%
# Split lines in each exercise:
splitted_exs = [ex.split('\n') for ex in separated_exs]
splitted_exs
# Out:
# [['1. Write a Pandas program to get the powers of an array values element-wise. ',
#   'Note: First array elements raised to powers from second array',
#   "Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}",
#   'Expected Output:',
#   'X Y Z',
#   '0 78 84 86',
#   '1 85 94 97',
#   '2 96 89 96',
#   '3 80 83 72',
#   '4 86 86 83'],
#  ['2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels. ',
#   'Sample Python dictionary data and list labels:',
#   "exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],",
#   "'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],",
#   "'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],",
#   "'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}",
#   "labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']",
#   'Expected Output:',
# ...

# %%
# Format each exercise: add '#### ' to the first line, '  ' to every line:
for ex_i, ex in enumerate(splitted_exs):
    for line_i, line in enumerate(ex):
        splitted_exs[ex_i][line_i] = '#### ' + line if line_i == 0 else line
        splitted_exs[ex_i][line_i] = splitted_exs[ex_i][line_i] + '  '

# %%
splitted_exs
# Out:
# [['#### 1. Write a Pandas program to get the powers of an array values element-wise.   ',
#   'Note: First array elements raised to powers from second array  ',
#   "Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}  ",
#   'Expected Output:  ',
#   'X Y Z  ',
#   '0 78 84 86  ',
#   '1 85 94 97  ',
#   '2 96 89 96  ',
#   '3 80 83 72  ',
#   '4 86 86 83  '],
#  ['#### 2. Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.   ',
#   'Sample Python dictionary data and list labels:  ',
#   "exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],  ",
#   "'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],  ",
#   "'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],  ",
#   "'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}  ",
#   "labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']  ",
# ...

# %%
# Save to a new file:
with open('processed_pd_data_frame.txt', 'w') as file:
    for ex in splitted_exs:
        for line in ex:
            print(line, file=file)
        print("", file=file)
